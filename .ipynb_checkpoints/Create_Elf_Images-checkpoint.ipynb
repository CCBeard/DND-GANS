# %% [markdown]
# This is a test run to see how well we can make elf images with a discriminator, basing them off of what we've done previously

# %%
# example of defining the discriminator model
import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.utils.vis_utils import plot_model
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import psutil
import gc
# Out:
# 2022-09-16 14:11:54.509631: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def Make_Consistent_Size(image, dimensions=[240, 360]):
    '''
    Very simple function
    '''
    
    return cv.resize(image, dimensions)

def RAM_Usage():
    # Getting loadover15 minutes
    load1, load5, load15 = psutil.getloadavg()
    cpucount = psutil.cpu_count()

    cpu_usage = (load1/os.cpu_count())

    print("Number of Available CPUS: {}".format(cpucount))
    print("Number of CPU's used in last minute: {}".format(load1))
    print("The CPU usage is : ", cpu_usage*100)

# %%
# output_directory = '/Volumes/BigBoi/DND_Images/Elf_Clean/'

# for i in range(1000):
#     try:
#         name = 'elf_{}.jpg'.format(i)
#         image = mpimg.imread('/Volumes/BigBoi/DND_Images/Elf/{}'.format(name))
#         image = Make_Consistent_Size(image)
#         plt.imshow(image)
#         plt.show()
#         max_val = np.max(image)
#         print(max_val)
#         if max_val < 200:
#             image = cv.convertScaleAbs(image, alpha=(255.0))


#         result= cv.imwrite(output_directory+'{}'.format(name), image)
#         if result==True:
#             print("File saved successfully")
#         else:
#             print("Error in saving file")
#     except FileNotFoundError:
#         continue

# %%
#gather our dataset
def Get_Training_Data(directory, n=1000):
    training_data = []
    for i in range(n):
        try:
            name = 'elf_{}.jpg'.format(i)
            image = mpimg.imread(directory+'{}'.format(name))
            training_data.append(image)
        except FileNotFoundError:
            continue

    return np.asarray(training_data)

# %%
# define the standalone discriminator model
def define_discriminator(in_shape=(360,240,3)):
    model = Sequential()
    model.add(Conv2D(64, (3,3), strides=(2, 2), padding='same', input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Conv2D(64, (3,3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# define model
model = define_discriminator()
# summarize the model
model.summary()
# plot the model
plot_model(model, to_file='discriminator_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 180, 120, 64)      1792
#
#  leaky_re_lu (LeakyReLU)     (None, 180, 120, 64)      0
#
#  dropout (Dropout)           (None, 180, 120, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 90, 60, 64)        36928
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 90, 60, 64)        0
#
#  dropout_1 (Dropout)         (None, 90, 60, 64)        0
#
#  flatten (Flatten)           (None, 345600)            0
#
#  dense (Dense)               (None, 1)                 345601
#
# =================================================================
# Total params: 384,321
# Trainable params: 384,321
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-16 14:12:00.336476: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/corey/anaconda3/envs/gansenv/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    # choose random instances
    ix = np.random.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[ix]
    # generate 'real' class labels (1)
    y = np.ones((n_samples, 1))
    return X, y

# generate n fake samples with class labels
def generate_fake_samples(n_samples):
    # generate uniform random numbers in [0,1]
    X = np.random.rand(360 * 240 * 3 * n_samples)
    # reshape into a batch of grayscale images
    X = X.reshape((n_samples, 360, 240, 3))
    # generate 'fake' class labels (0)
    y = np.zeros((n_samples, 1))
    return X, y

# %%
# train the discriminator model
def train_discriminator(model, dataset, n_iter=100, n_batch=32):
    half_batch = int(n_batch / 2)
    # manually enumerate epochs
    for i in range(n_iter):
        # get randomly selected 'real' samples
        X_real, y_real = generate_real_samples(dataset, half_batch)
        # update discriminator on real samples
        _, real_acc = model.train_on_batch(X_real, y_real)
        # generate 'fake' examples
        X_fake, y_fake = generate_fake_samples(half_batch)
        # update discriminator on fake samples
        _, fake_acc = model.train_on_batch(X_fake, y_fake)
        # summarize performance
        print('>%d real=%.0f%% fake=%.0f%%' % (i+1, real_acc*100, fake_acc*100))

# %%
# define the discriminator model
RAM_Usage()
model = define_discriminator()
# load image data
# fit the model
training_data = Get_Training_Data('/Volumes/BigBoi/DND_Images/Elf_Clean/')
RAM_Usage()
train_discriminator(model, training_data)
RAM_Usage()
# Out:
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 2.3271484375
# The CPU usage is :  29.08935546875
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 2.220703125
# The CPU usage is :  27.7587890625
# >1 real=25% fake=0%
# >2 real=100% fake=0%
# >3 real=100% fake=0%
# >4 real=100% fake=0%
# >5 real=100% fake=0%
# >6 real=100% fake=0%
# >7 real=100% fake=0%
# >8 real=100% fake=0%
# >9 real=100% fake=0%
# >10 real=100% fake=0%
# >11 real=100% fake=0%
# >12 real=100% fake=0%
# >13 real=100% fake=0%
# >14 real=100% fake=0%
# >15 real=100% fake=0%
# >16 real=100% fake=0%
# >17 real=100% fake=0%
# >18 real=100% fake=0%
# >19 real=100% fake=12%
# >20 real=100% fake=100%
# >21 real=62% fake=0%
# >22 real=100% fake=0%
# >23 real=100% fake=0%
# >24 real=100% fake=0%
# >25 real=100% fake=0%
# >26 real=100% fake=0%
# >27 real=100% fake=0%
# >28 real=100% fake=0%
# >29 real=100% fake=0%
# >30 real=100% fake=0%
# >31 real=100% fake=0%
# >32 real=100% fake=0%
# >33 real=100% fake=0%
# >34 real=100% fake=0%
# >35 real=100% fake=0%
# >36 real=100% fake=0%
# >37 real=100% fake=0%
# >38 real=100% fake=0%
# >39 real=100% fake=0%
# >40 real=100% fake=0%
# >41 real=100% fake=0%
# >42 real=100% fake=12%
# >43 real=94% fake=0%
# >44 real=100% fake=0%
# >45 real=100% fake=0%
# >46 real=100% fake=0%
# >47 real=100% fake=0%
# >48 real=100% fake=0%
# >49 real=100% fake=25%
# >50 real=100% fake=100%
# >51 real=100% fake=100%
# >52 real=100% fake=100%
# >53 real=100% fake=100%
# >54 real=100% fake=100%
# >55 real=100% fake=100%
# >56 real=88% fake=0%
# >57 real=100% fake=0%
# >58 real=100% fake=0%
# >59 real=100% fake=0%
# >60 real=100% fake=0%
# >61 real=100% fake=0%
# >62 real=100% fake=0%
# >63 real=100% fake=0%
# >64 real=100% fake=0%
# >65 real=100% fake=0%
# >66 real=100% fake=0%
# >67 real=100% fake=25%
# >68 real=100% fake=94%
# >69 real=100% fake=100%
# >70 real=100% fake=100%
# >71 real=100% fake=100%
# >72 real=100% fake=100%
# >73 real=100% fake=100%
# >74 real=100% fake=100%
# >75 real=100% fake=100%
# >76 real=100% fake=100%
# >77 real=100% fake=100%
# >78 real=100% fake=100%
# >79 real=100% fake=100%
# >80 real=100% fake=100%
# >81 real=100% fake=100%
# >82 real=100% fake=100%
# >83 real=100% fake=100%
# >84 real=100% fake=100%
# >85 real=100% fake=100%
# >86 real=100% fake=100%
# >87 real=100% fake=100%
# >88 real=100% fake=100%
# >89 real=94% fake=100%
# >90 real=100% fake=0%
# >91 real=100% fake=0%
# >92 real=100% fake=12%
# >93 real=100% fake=88%
# >94 real=100% fake=100%
# >95 real=100% fake=100%
# >96 real=100% fake=100%
# >97 real=100% fake=100%
# >98 real=100% fake=100%
# >99 real=100% fake=100%
# >100 real=100% fake=100%
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 5.79345703125
# The CPU usage is :  72.418212890625

# %%
RAM_Usage()
# del(training_data)
# gc.collect()
# RAM_Usage()
# Out:
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 2.21142578125
# The CPU usage is :  27.642822265625

# %%
from numpy import zeros
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from matplotlib import pyplot
 
# define the standalone generator model
def define_generator(latent_dim):
	model = Sequential()
	# foundation for 90x60x3 image
	n_nodes = 128 * 90 * 60
	model.add(Dense(n_nodes, input_dim=latent_dim))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Reshape((90, 60, 128)))
	# upsample to 180x120
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# upsample to 360x240
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2D(3, (90,60), activation='sigmoid', padding='same'))
	return model
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input
 
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = g_model.predict(x_input)
	# create 'fake' class labels (0)
	y = zeros((n_samples, 1))
	return X, y
 
# size of the latent space
latent_dim = 100
# define the discriminator model
model = define_generator(latent_dim)
# generate samples
n_samples = 25
X, _ = generate_fake_samples(model, latent_dim, n_samples)
# plot the generated samples
for i in range(n_samples):
	# define subplot
	pyplot.subplot(5, 5, 1 + i)
	# turn off axis labels
	pyplot.axis('off')
	# plot single image
	pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
# show the figure
pyplot.show()
RAM_Usage()
# Out:
# 1/1 [==============================] - 273s 273s/step
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 8.9462890625
# The CPU usage is :  111.82861328125

# %%
del(X)
gc.collect()
RAM_Usage()
# Out:
# Number of Available CPUS: 8
# Number of CPU's used in last minute: 3.09765625
# The CPU usage is :  38.720703125

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
	# make weights in the discriminator not trainable
	d_model.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(g_model)
	# add the discriminator
	model.add(d_model)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %%
# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# summarize gan model
gan_model.summary()
# plot gan model
plot_model(gan_model, to_file='gan_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_5 (Sequential)   (None, 360, 240, 3)       72409347
#
#  sequential_4 (Sequential)   (None, 1)                 384321
#
# =================================================================
# Total params: 72,793,668
# Trainable params: 72,409,347
# Non-trainable params: 384,321
# _________________________________________________________________

# %%
# create and save a plot of generated images (reversed grayscale)
def save_plot(examples, epoch, n=10):
	# plot images
	for i in range(n * n):
		# define subplot
		pyplot.subplot(n, n, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename = 'generated_plot_e%03d.png' % (epoch+1)
	pyplot.savefig(filename)
	pyplot.close()
 
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=100):
	# prepare real samples
	X_real, y_real = generate_real_samples(dataset, n_samples)
	# evaluate discriminator on real examples
	_, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
	# prepare fake examples
	x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
	# evaluate discriminator on fake examples
	_, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
	# summarize discriminator performance
	print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
	# save plot
	save_plot(x_fake, epoch)
	# save the generator model tile file
	filename = 'generator_model_%03d.h5' % (epoch + 1)
	g_model.save(filename)
 
# train the generator and discriminator
def train(g_model, d_model, gan_model, latent_dim, n_epochs=5, n_batch=32):
    dataset = Get_Training_Data('/Volumes/BigBoi/DND_Images/Elf_Clean/')
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    del(dataset)
    gc.collect()
    # manually enumerate epochs
    for i in range(n_epochs):
        # enumerate batches over the training set
        for j in range(bat_per_epo):
            RAM_Usage()
            dataset = Get_Training_Data('/Volumes/BigBoi/DND_Images/Elf_Clean/')
            # get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            # create training set for the discriminator
            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            # update discriminator model weights
            d_loss, _ = d_model.train_on_batch(X, y)
            # prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            # create inverted labels for the fake samples
            y_gan = np.ones((n_batch, 1))
            # update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)
            # summarize loss on this batch
            print('>%d, %d/%d, d=%.3f, g=%.3f' % (i+1, j+1, bat_per_epo, d_loss, g_loss))
            del(dataset)
            del(X_real)
            del(y_real)
            del(X_fake)
            del(y_fake)
            del(X)
            del(y)
            gc.collect()
        # evaluate the model performance, sometimes
        if (i+1) % 10 == 0:
            summarize_performance(i, g_model, d_model, dataset, latent_dim)
 
# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
# train model
train(g_model, d_model, gan_model, latent_dim)
# Out:
# 1/1 [==============================] - 196s 196s/step
